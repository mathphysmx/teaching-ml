# %% [markdown]
# Description and images of [GeoDataSets](https://github.com/GeostatsGuy/GeoDataSets) in Michael Pyrcz GitHub.

# %% [markdown]
# # 12_sample_data.csv

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/GeostatsGuy/GeoDataSets/master/12_sample_data.csv"
x = pd.read_csv(url, index_col=0)
x.describe()
# Out:
#                 X           Y      Facies    Porosity          Perm  \
# count  480.000000  480.000000  480.000000  480.000000    480.000000
# mean   430.187500  522.166667    0.616667    0.189440    520.932093
# std    263.832692  284.293420    0.486706    0.031702   1226.207190
# min      0.000000   19.000000    0.000000    0.117562      0.005776
# 25%    200.000000  279.000000    0.000000    0.165884      6.539988
# 50%    390.000000  539.000000    1.000000    0.185443     49.451463
# 75%    630.000000  759.000000    1.000000    0.216513    369.470756
# max    980.000000  999.000000    1.000000    0.261091  10319.904849
#
#                 AI
# count   480.000000
# mean   3758.879653
# std     779.990582
# min    1746.387548
# 25%    3212.900121
# 50%    3719.883000
# 75%    4236.160395
# max    6194.573653

# %%
x.sample(11)
# Out:
#          X      Y  Facies  Porosity         Perm           AI
# 723  220.0   89.0     0.0  0.148165     1.272000  5133.396418
# 559  270.0  929.0     1.0  0.224358   414.193338  2773.675697
# 636  390.0  509.0     0.0  0.158405    73.762228  3283.993800
# 763  300.0  399.0     1.0  0.221155  1757.173869  3887.667137
# 736  580.0  709.0     0.0  0.178090     8.547194  4753.007205
# 274  750.0  550.0     0.0  0.157177     1.859946  3686.720378
# 655  240.0  759.0     1.0  0.223354   114.238644  3066.707994
# 436  590.0  589.0     1.0  0.152834    38.441590  4110.050105
# 673  370.0  929.0     1.0  0.231597   601.006065  3963.600552
# 615  560.0  889.0     0.0  0.167263   531.630597  4474.776077
# 730  330.0  179.0     1.0  0.232082   551.947407  3778.189485
